# %%
#1. Build a Flask app that scrapes data from multiple websites and displays it on your site.You can try to scrap websites like youtube ,
#amazon and show data on output pages and deploy it on cloud platform .
#ans:
import pandas as pd
import requests
from bs4 import BeautifulSoup
Product_name=[]
Prices=[]
Description=[]
Reviews=[]

for i in range(2,12):
    url="https://www.flipkart.com/search?q=mobiles+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page="+str(i)
    r=requests.get(url)
    #print(r)
    soup=BeautifulSoup(r.text,"lxml")
    

    names = soup.find_all("div",class_="_4rR01T")
    for i in names:
        name = i.text
        Product_name.append(name)
    #print(Product_name)

    prices=soup.find_all("div",class_="_30jeq3 _1_WHN1")

    for i in prices:
        name=i.text
        Prices.append(name)
    #print(Prices)

    desc=soup.find_all("ul",class_="_1xgFaf")

    for i in desc:
        name=i.text
        Description.append(name)
    #print(Description)

    


#print(len(Reviews))


    #print(soup)
    #while True:
    #np=soup.find("a",class_="_1LKTO3").get("href")
    #cnp="https://www.flipkart.com"+np
    #print(cnp)


    #url=cnp
    #r=requests.get(url)
    #soup=BeautifulSoup(r.text,"lxml")
    
    
df=pd.DataFrame({"Product Names":Product_name,"Price":Prices,"Description":Description})
df.to_csv("C:/Users/aipee/OneDrive/Pictures/Flipkart_mobiles_under_50000.csv")

# %% [markdown]
# ![1.live.jpg](attachment:6ad44977-6e4b-450c-9945-649417770224.jpg)![1.code 2.jpg](attachment:81b25d58-3cfb-4013-9cd1-58cf3ec5d947.jpg)![1.code.jpg](attachment:e56b0789-e6cc-43ee-a671-4d1def5bb378.jpg)

# %%
#2. Create a Flask app that consumes data from external APIs and displays it to users.
#Try to find an public API which will give you a data and based on that call it and deploy it on cloud platform
#ans:

# %% [markdown]
# ![2.live.jpg](attachment:e1384d83-62cb-4f6d-a123-2b55e0c2c33b.jpg)![2.code.jpg](attachment:c87494f7-935a-40dd-9ff4-bd2160f7b8f8.jpg)![2.live code.jpg](attachment:5c59cfb7-06ac-4306-b363-040afd33a412.jpg)

# %%
#3. Implement OAuth2 authentication to allow users to log in using their Google or Facebook accounts.
#ans:

# %% [markdown]
# ![p3.code5.jpg](attachment:e2b30d67-484f-4676-9ea4-8370ee93534a.jpg)![p3.code1.jpg](attachment:7db89c7d-25f0-4271-b602-2828872562dd.jpg)![p3.code2.jpg](attachment:9a41250a-e71b-4464-81be-274ad45af569.jpg)![p3.code4.jpg](attachment:969b2637-762e-42b1-825b-3016e61251f6.jpg)

# %%
#4. Develop a recommendation system using Flask that suggests content to users based on their preferences.
#ans:

# %% [raw]
# Developing a recommendation system using Flask involves several steps, including setting up the Flask application, integrating the recommendation algorithm, creating user interfaces, and handling user preferences. Below is a high-level outline of how you can achieve this:
#
# 1. **Set up Flask Application**: Start by creating a Flask application. You can do this by installing Flask using pip and creating a basic Flask app structure with routes.
#
# 2. **Data Collection and Preparation**: Gather data on user preferences and content. This could be in the form of ratings, likes, views, etc., for different content items (e.g., movies, articles, products). Prepare this data for use in your recommendation algorithm.
#
# 3. **Recommendation Algorithm**: Implement a recommendation algorithm. Common techniques include collaborative filtering, content-based filtering, and hybrid methods. You can use libraries like scikit-learn, TensorFlow, or PyTorch for implementing these algorithms.
#
# 4. **Integrate Algorithm with Flask**: Create Flask routes to handle user requests for recommendations. When a user makes a request, call the recommendation algorithm to generate personalized recommendations based on the user's preferences.
#
# 5. **User Interface**: Design and implement user interfaces to interact with the recommendation system. This could be a web interface where users input their preferences and receive recommendations in return.
#
# 6. **Handling Preferences**: Allow users to provide feedback on recommendations (e.g., liking/disliking, rating). Update user preferences based on this feedback to improve future recommendations.
#
# 7. **Testing and Deployment**: Test your recommendation system thoroughly to ensure it's working as expected. Once satisfied, deploy your Flask application to a web server so that users can access it.
#
# Here's a basic example of how your Flask app structure might look:
#
# ```python
# from flask import Flask, request, jsonify
#
# app = Flask(__name__)
#
# # Dummy data for demonstration purposes
# user_preferences = {
#     "user1": {"genre": "action", "length": "long"},
#     "user2": {"genre": "comedy", "length": "short"}
# }
#
# # Dummy recommendation function
# def recommend(user_id):
#     # Implement your recommendation algorithm here
#     user_pref = user_preferences.get(user_id, {})
#     # Dummy recommendations for demonstration
#     recommendations = ["Movie 1", "Movie 2", "Movie 3"]
#     return recommendations
#
# @app.route('/recommendations', methods=['POST'])
# def get_recommendations():
#     data = request.json
#     user_id = data.get('user_id')
#     if user_id:
#         recommendations = recommend(user_id)
#         return jsonify({"recommendations": recommendations})
#     else:
#         return jsonify({"error": "User ID not provided"}), 400
#
# if __name__ == '__main__':
#     app.run(debug=True)
# ```
#
# In this example, when a POST request is made to `/recommendations` with JSON data containing a `user_id`, the `get_recommendations` function calls the `recommend` function to generate recommendations for that user based on their preferences.
#
# Remember, this is just a basic outline to get you started. Depending on your specific requirements and the complexity of your recommendation algorithm, you may need to make adjustments and enhancements to this structure.
