# %%
#Intermediate Flask Topics:

# %%
#6. Build a Flask app that allows users to upload files and display them on the website.
#ans:

# %% [markdown]
# ![6(web).jpg](attachment:f928bf65-4aac-4fe9-b9fc-351928464832.jpg)![6(html).jpg](attachment:839acfa7-9da3-48f3-bef1-5773b4edde7e.jpg)![6(py).jpg](attachment:1e7bf103-18dd-415e-9651-f68d8e9ba3f1.jpg)![6(result).jpg](attachment:c8ba5fd7-a041-4b6a-8e37-08a05810c569.jpg)

# %%
#7. Integrate a SQLite database with Flask to perform CRUD operations on a list of items.
#ans:

# %% [markdown]
# ![7.jpg](attachment:65814afa-b079-4b3d-986d-23ed1752878d.jpg)![7.1.jpg](attachment:7f2f085f-8bf1-4a11-8a1a-e721f54304c7.jpg)![7.2.jpg](attachment:e439fa5b-9fa7-42ee-9477-0642fd0af223.jpg)![7.3.jpg](attachment:2ee8b9dc-0eef-4911-93ed-40bb37a75b27.jpg)

# %%
#8. Implement user authentication and registration in a Flask app using Flask-Login.
#ans:

# %% [markdown]
# ![code.1.jpg](attachment:c7a07d85-6023-4cd8-baf9-02ffb79cdc46.jpg)

# %% [markdown]
# ![login form.jpg](attachment:db612af9-68e4-4c56-a838-b0a84cb6ba5e.jpg)
