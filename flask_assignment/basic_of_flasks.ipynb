# %%
#Basics of Flask

# %%
#1. Create a Flask app that displays "Hello, World!" on the homepage.
#ans:

# %% [markdown]
# ![1.jpg](attachment:1f522cf0-fe6d-4bf7-84d4-e492eb4f0607.jpg)

# %% [markdown]
# ![1(a).jpg](attachment:9f1d9327-468d-47bd-9ddb-28cba751786c.jpg)

# %%
#2. Build a Flask app with static HTML pages and navigate between them.
#ans:

# %% [markdown]
# ![2.jpg](attachment:2e26acf1-1ceb-4046-8170-fbf350fa252d.jpg)

# %% [markdown]
# ![2(a.1).jpg](attachment:96de5fc9-8f41-48cb-a528-41ed6a217b8f.jpg)

# %% [markdown]
# ![2(a.2).jpg](attachment:cb3639c0-a43f-4363-9341-f2ebc64ff086.jpg)![2(a.3).jpg](attachment:3cfda749-f625-4bd3-98d5-8694fbce9930.jpg)!

# %%
#3. Develop a Flask app that uses URL parameters to display dynamic content.
#ans:

# %% [markdown]
# ![3.jpg](attachment:e72695da-5dbd-4b80-86f2-b1f0a888a825.jpg)![3.(a.1).jpg](attachment:2e8908ca-88ac-45db-a780-abfba1648537.jpg)![3.(a.2).jpg](attachment:66afcf61-f6e9-4dfe-bc36-5ea7d0b5af21.jpg)

# %%
#4. Create a Flask app with a form that accepts user input and displays it
#ans:

# %% [markdown]
# ![4(a.1).jpg](attachment:a95bb449-8a41-467b-b37a-192ba7637e7a.jpg)![4.jpg](attachment:f8ae1a63-aa34-4a78-9fb4-fea9e8fff111.jpg)![4(a.2).jpg](attachment:31057f7f-d92d-4123-a43b-945c75fa8221.jpg)

# %%
#5. Implement user sessions in a Flask app to store and display user-specific data.
#ans:

# %% [markdown]
# ![5.0.jpg](attachment:7f1a4270-14aa-4d1d-af20-1a973b767322.jpg)

# %% [markdown]
# ![5.(a.2).jpg](attachment:024399c4-f890-48f5-ac29-362c110507e4.jpg)![5.(a.1).jpg](attachment:4dc39247-7a45-4b8d-a8f1-87c2307759d6.jpg)
